# %%
f = open('JKG.json', 'a')
f.write('{"nodes" : [\n')
f.write('{"labels":["Source"], "properties":{"id":"EHR:EHR", "name":"Electronic health records.", "sab":"EHR"}}\n')
f.write(',{"labels":["Rel_Label"], "properties": {"id":"EHR:C12", "def":"Patient has the related feature across specified years.", "rel_label":"has_feature", "sab":"EHR"}}\n')
f.write(',{"labels":["Node_Label"], "properties": {"id":"EHR:C1", "def":"A unique person from one electronic health record collection.", "node_label":"Patient", "sab":"EHR"}}\n')
for i in list(range(0,10000)):
    f.write(',{"labels" : ["Concept", "Patient"],"properties" : {"id" : "EHR:'+str(i)+'","sab" : "EHR","pref_term" : "Patient"}}\n')
f.write('],"rels" : [\n')
f.write('{"label":"has_feature","end":{"properties":{"id": "EHR:0"}},"properties":{"sab":"EHR"},"start":{"properties":{"id": "EHR:1"}}}\n')
for i in list(range(1,9999)):
    f.write(',{"label":"has_feature","end":{"properties":{"id": "EHR:'+str(i)+'"}},"properties":{"sab":"EHR"},"start":{"properties":{"id": "EHR:'+str(i+1)+'"}}}\n')
f.write(']}')
f.close()
